# %% [markdown]
# # Note
#
# Databricks Free Edition uses Serverless Compute, which does not support Spark `cache()` / `persist()`.
#
# This notebook explains the concept of caching, demonstrates the syntax, and documents the platform limitation encountered during implementation.

# %%
# %sql
DESCRIBE DETAIL workspace.nyc_taxi.silver_trips;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
OPTIMIZE workspace.nyc_taxi.silver_trips;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>metrics</th></tr></thead><tbody><tr><td></td><td>List(3, 6, List(39899966, 59530918, 5.2977625666666664E7, 3, 158932877), List(9878671, 29072725, 2.5792855166666668E7, 6, 154757131), 0, null, null, 0, 1, 6, 0, true, 0, 0, 1785143320776, 1785143326129, 8, 3, null, List(0, 0), null, 19, 19, 5267, 0, null, null)</td></tr></tbody></table></div>

# %%
# %sql
DESCRIBE DETAIL workspace.nyc_taxi.silver_trips;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
DESCRIBE HISTORY workspace.nyc_taxi.silver_trips;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
OPTIMIZE workspace.nyc_taxi.silver_trips
ZORDER BY (VendorID);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>metrics</th></tr></thead><tbody><tr><td></td><td>List(2, 3, List(77218275, 82272291, 7.9745283E7, 2, 159490566), List(39899966, 59530918, 5.2977625666666664E7, 3, 158932877), 0, List(minCubeSize(107374182400), List(0, 0), List(3, 158932877), 0, List(3, 158932877), 1, null), null, 0, 1, 3, 0, false, 0, 0, 1785143433821, 1785143442160, 8, 1, null, List(0, 0), null, 19, 19, 7796, 0, null, null)</td></tr></tbody></table></div>

# %%
# %sql
DESCRIBE HISTORY workspace.nyc_taxi.silver_trips;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
DESCRIBE HISTORY workspace.nyc_taxi.silver_trips;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
VACUUM workspace.nyc_taxi.silver_trips DRY RUN;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th></tr></thead><tbody></tbody></table></div>
