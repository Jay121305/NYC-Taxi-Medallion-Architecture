# %%
# %sql
EXPLAIN
SELECT *
FROM workspace.nyc_taxi.silver_trips
WHERE VendorID = 2;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>plan</th></tr></thead><tbody><tr><td>== Physical Plan ==
# PhotonResultStage
# +- PhotonColumnarToRow
# ...

# %%
# %sql
EXPLAIN FORMATTED

SELECT *

FROM workspace.nyc_taxi.silver_trips

WHERE VendorID = 2;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>plan</th></tr></thead><tbody><tr><td>== Physical Plan ==
# PhotonResultStage (3)
# +- PhotonColumnarToRow (2)
#    +- PhotonScan parquet workspace.nyc_taxi.silver_trips (1)
#
#
# (1) PhotonScan parquet workspace.nyc_taxi.silver_trips
# ...

# %%
# %sql
EXPLAIN FORMATTED

SELECT
VendorID,
COUNT(*) AS trips

FROM workspace.nyc_taxi.silver_trips

GROUP BY VendorID;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>plan</th></tr></thead><tbody><tr><td>== Physical Plan ==
# AdaptiveSparkPlan (9)
# +- == Initial Plan ==
#    PhotonResultStage (8)
#    +- PhotonColumnarToRow (7)
#       +- PhotonGroupingAgg (6)
#          +- PhotonShuffleExchangeSource (5)
#             +- PhotonShuffleMapStage (4)
#                +- PhotonShuffleExchangeSink (3)
#                   +- PhotonGroupingAgg (2)
#                      +- PhotonScan parquet workspace.nyc_taxi.silver_trips (1)
#
#
# (1) PhotonScan parquet workspace.nyc_taxi.silver_trips
# Output [1]: [VendorID#15663]
# ...

# %%
# %sql
EXPLAIN FORMATTED

SELECT
s.PULocationID,
z.Zone

FROM workspace.nyc_taxi.silver_trips s

JOIN workspace.nyc_taxi.gold_zone_summary z

ON s.PULocationID = z.PULocationID;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
